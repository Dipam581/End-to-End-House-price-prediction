# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Dataset/house_prices.csv')

# %%
df.head(5)
# Out:
#    Index                                              Title  \
# 0      0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1      1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2      2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3      3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4      4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
#
#    Price (in rupees) location Carpet Area         Status         Floor  \
# 0             6000.0    thane    500 sqft  Ready to Move  10 out of 11
# ...

# %% [markdown]
# ##EDA

# %%
len(df.columns)
# Out:
# 21

# %%
df.isnull().sum()
# Out:
# Index                     0
# Title                     0
# Description            3023
# Amount(in rupees)         0
# Price (in rupees)     17665
# location                  0
# Carpet Area           80673
# Status                  615
# Floor                  7077
# Transaction              83
# Furnishing             2897
# facing                70233
# overlooking           81436
# Society              109678
# Bathroom                828
# Balcony               48935
# Car Parking          103357
# Ownership             65517
# Super Area           107685
# Dimensions           187531
# Plot Area            187531
# dtype: int64

# %%
df = df.drop(['Plot Area', 'Car Parking','Dimensions','Balcony','Super Area','Title','Society','Description','Status','overlooking','Ownership','Transaction'],axis='columns')

# %%
# df.drop(['Dimensions'],axis=1,inplace=True)

# %%
# df["Plot Area"].value_counts()

# %%
# df.drop(['Plot Area'],axis=1,inplace=True)

# %%
df.tail(5)
# Out:
#          Index Amount(in rupees)  Price (in rupees)  location Carpet Area  \
# 187526  187526           63 Lac              3225.0  zirakpur         NaN
# 187527  187527           55 Lac              3274.0  zirakpur         NaN
# 187528  187528           76 Lac              4343.0  zirakpur   1250 sqft
# 187529  187529           30 Lac              4231.0  zirakpur         NaN
# 187530  187530          1.18 Cr              6162.0  zirakpur         NaN
#
#               Floor      Furnishing        facing Bathroom
# 187526   2 out of 4  Semi-Furnished          East        3
# 187527   4 out of 6     Unfurnished  North - East        3
# 187528   1 out of 3       Furnished          East        3
# 187529   2 out of 2  Semi-Furnished           NaN        2
# 187530  5 out of 13  Semi-Furnished  North - East        4

# %%
df.head(5)
# Out:
#    Index Amount(in rupees)  Price (in rupees) location Carpet Area  \
# 0      0           42 Lac              6000.0    thane    500 sqft
# 1      1           98 Lac             13799.0    thane    473 sqft
# 2      2          1.40 Cr             17500.0    thane    779 sqft
# 3      3           25 Lac                 NaN    thane    530 sqft
# 4      4          1.60 Cr             18824.0    thane    635 sqft
#
#           Floor      Furnishing facing Bathroom
# 0  10 out of 11     Unfurnished    NaN        1
# 1   3 out of 22  Semi-Furnished   East        2
# 2  10 out of 29     Unfurnished   East        2
# 3    1 out of 3     Unfurnished    NaN        1
# 4  20 out of 42     Unfurnished   West        2

# %%
df.isna().sum()
# Out:
# Index                    0
# Amount(in rupees)        0
# Price (in rupees)    17665
# location                 0
# Carpet Area          80673
# Floor                 7077
# Furnishing            2897
# facing               70233
# Bathroom               828
# dtype: int64

# %%
df["Price (in rupees)"] = df["Price (in rupees)"].transform(lambda x: x.fillna(x.mean()))

# %%
df.head(10)
# Out:
#    Index Amount(in rupees)  Price (in rupees) location Carpet Area  \
# 0      0           42 Lac         6000.000000    thane    500 sqft
# 1      1           98 Lac        13799.000000    thane    473 sqft
# 2      2          1.40 Cr        17500.000000    thane    779 sqft
# 3      3           25 Lac         7583.771885    thane    530 sqft
# 4      4          1.60 Cr        18824.000000    thane    635 sqft
# 5      5           45 Lac         6618.000000    thane         NaN
# 6      6         16.5 Lac         2538.000000    thane    550 sqft
# 7      7           60 Lac        10435.000000    thane         NaN
# 8      8           60 Lac        10000.000000    thane         NaN
# 9      9          1.60 Cr        11150.000000    thane    900 sqft
#
#              Floor      Furnishing facing Bathroom
# 0     10 out of 11     Unfurnished    NaN        1
# 1      3 out of 22  Semi-Furnished   East        2
# 2     10 out of 29     Unfurnished   East        2
# ...

# %%
df.info()
df.shape
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              187531 non-null  int64
#  1   Amount(in rupees)  187531 non-null  object
#  2   Price (in rupees)  187531 non-null  float64
#  3   location           187531 non-null  object
#  4   Carpet Area        106858 non-null  object
#  5   Floor              180454 non-null  object
#  6   Furnishing         184634 non-null  object
#  7   facing             117298 non-null  object
#  8   Bathroom           186703 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 12.9+ MB
# Index                    0
# Amount(in rupees)        0
# Price (in rupees)        0
# location                 0
# Carpet Area          80673
# Floor                 7077
# Furnishing            2897
# facing               70233
# Bathroom               828
# ...

# %%
# df["Carpet Area"] = df["Carpet Area"].transform(lambda x: x.fillna(x.mean()))

def calculate_carpetArea():
  total = 0
  count = 0
  for i in df["Carpet Area"]:
    try:
      if i.lower() != "nan":
        total += int(i.split(" ")[0])
        count += 1
    except:
      pass
  return total, count

ca, count = calculate_carpetArea()
print(ca)
print(ca/count)
print(ca/df["Carpet Area"].count())
# Out:
# 128207714
# 1199.7951861348706
# 1199.7951861348706

# %%
df['Carpet Area'] = df['Carpet Area'].transform(lambda x: x.fillna(float(ca/count)))

# %%
df["Carpet Area"] = df["Carpet Area"].astype(str).transform(lambda x: x.split(" ")[0])
df.head(10)

df["Carpet Area"] = df["Carpet Area"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              187531 non-null  int64
#  1   Amount(in rupees)  187531 non-null  object
#  2   Price (in rupees)  187531 non-null  float64
#  3   location           187531 non-null  object
#  4   Carpet Area        187531 non-null  float64
#  5   Floor              180454 non-null  object
#  6   Furnishing         184634 non-null  object
#  7   facing             117298 non-null  object
#  8   Bathroom           186703 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 12.9+ MB

# %%
df.head(7)
# Out:
#    Index Amount(in rupees)  Price (in rupees) location  Carpet Area  \
# 0      0           42 Lac         6000.000000    thane   500.000000
# 1      1           98 Lac        13799.000000    thane   473.000000
# 2      2          1.40 Cr        17500.000000    thane   779.000000
# 3      3           25 Lac         7583.771885    thane   530.000000
# 4      4          1.60 Cr        18824.000000    thane   635.000000
# 5      5           45 Lac         6618.000000    thane  1199.795186
# 6      6         16.5 Lac         2538.000000    thane   550.000000
#
#           Floor      Furnishing facing Bathroom
# 0  10 out of 11     Unfurnished    NaN        1
# 1   3 out of 22  Semi-Furnished   East        2
# 2  10 out of 29     Unfurnished   East        2
# 3    1 out of 3     Unfurnished    NaN        1
# 4  20 out of 42     Unfurnished   West        2
# 5    2 out of 7     Unfurnished   East        1
# 6    4 out of 5     Unfurnished    NaN        1

# %%
# df["Transaction"].value_counts()

# %%
def convert_rupees(amount_str):
    try:
        parts=amount_str.split()
        amount=float(parts[0])

        if len(parts)>1:
            unit=parts[1].strip()
            if unit=='Lac':
                amount*=100000
            elif unit=='Cr':
                amount*=10000000
        return amount
    except(ValueError,IndexError):
        return None

df['Amount(in rupees)']= df['Amount(in rupees)'].apply(convert_rupees)

# %%
df.rename(columns={'Amount(in rupees)': 'Amount_in_rupees', 'Price (in rupees)': 'Price_in_rupees', 'Carpet Area': 'Carpet_Area_in_sqft'}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Index                      0
# Amount_in_rupees        9684
# Price_in_rupees            0
# location                   0
# Carpet_Area_in_sqft        0
# Floor                   7077
# Furnishing              2897
# facing                 70233
# Bathroom                 828
# dtype: int64

# %%
# df = df.drop(["Transaction", ""],axis='columns')

# %%
df.info()

# dummies = pd.get_dummies(df.location,dummy_na=False,dtype=int)
# df = pd.concat([df,dummies],axis='columns'  )

df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Index                187531 non-null  int64
#  1   Amount_in_rupees     177847 non-null  float64
#  2   Price_in_rupees      187531 non-null  float64
#  3   location             187531 non-null  object
#  4   Carpet_Area_in_sqft  187531 non-null  float64
#  5   Floor                180454 non-null  object
#  6   Furnishing           184634 non-null  object
#  7   facing               117298 non-null  object
#  8   Bathroom             186703 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 12.9+ MB
#    Index  Amount_in_rupees  Price_in_rupees location  Carpet_Area_in_sqft  \
# 0      0         4200000.0      6000.000000    thane           500.000000
# 1      1         9800000.0     13799.000000    thane           473.000000
# ...

# %%
df["Bathroom"] = pd.to_numeric(df["Bathroom"], errors='coerce')

# %%
# df.drop('overlooking',axis='columns',inplace=True)

# %%
# df.drop('location',axis='columns',inplace=True)

# %%
df.head(10)
df.to_csv("Dataset/processed_house_prices.csv", index=False)

# %%
from sklearn.preprocessing import LabelEncoder
# Function to perform Label Encoding for multiple columns
def label_encode_multiple(df, columns):
    le = LabelEncoder()
    for column in columns:
        df[column] = le.fit_transform(df[column])
    return df

label_encode_columns = ['Floor', 'Furnishing', 'facing', 'location']
df = label_encode_multiple(df, label_encode_columns)

# %%
df["Amount_in_rupees"] = df["Amount_in_rupees"].transform(lambda x: x.fillna(x.mean()))

# %%
df["Bathroom"] = df["Bathroom"].transform(lambda x: x.fillna(x.mean()))

# %%
cols = df.columns

# %%
# for col in cols:
#   print(col,df[col].isna().sum())

# %% [markdown]
# ##Model building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Index                187531 non-null  int64
#  1   Amount_in_rupees     187531 non-null  float64
#  2   Price_in_rupees      187531 non-null  float64
#  3   location             187531 non-null  int32
#  4   Carpet_Area_in_sqft  187531 non-null  float64
#  5   Floor                187531 non-null  int32
#  6   Furnishing           187531 non-null  int32
#  7   facing               187531 non-null  int32
#  8   Bathroom             187531 non-null  float64
# dtypes: float64(4), int32(4), int64(1)
# memory usage: 10.0 MB

# %%
df.drop("Index",axis='columns',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Amount_in_rupees     187531 non-null  float64
#  1   Price_in_rupees      187531 non-null  float64
#  2   location             187531 non-null  int32
#  3   Carpet_Area_in_sqft  187531 non-null  float64
#  4   Floor                187531 non-null  int32
#  5   Furnishing           187531 non-null  int32
#  6   facing               187531 non-null  int32
#  7   Bathroom             187531 non-null  float64
# dtypes: float64(4), int32(4)
# memory usage: 8.6 MB

# %%
X = df.drop('Amount_in_rupees',axis='columns')
Y = df.Amount_in_rupees

# %%
X.head(5)
# Out:
#    Price_in_rupees  location  Carpet_Area_in_sqft  Floor  Furnishing  facing  \
# 0      6000.000000        67                500.0     40           2       8
# 1     13799.000000        67                473.0    551           1       0
# 2     17500.000000        67                779.0     58           2       0
# 3      7583.771885        67                530.0     24           2       8
# 4     18824.000000        67                635.0    381           2       7
#
#    Bathroom
# 0       1.0
# 1       2.0
# 2       2.0
# 3       1.0
# 4       2.0

# %%
X["Price_in_rupees"].isna().sum()
# Out:
# 0

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
# models = {
#     'Linear Regression': LinearRegression(),
#     'Decision Tree Regressor': DecisionTreeRegressor(),
#     'Random Forest': RandomForestRegressor(random_state=42),
#     'Knr': KNeighborsRegressor(),
#     'Gradient Boosting': GradientBoostingRegressor(random_state=42),
#     'XGBRegressor': XGBRegressor(),
#     # 'Support Vector Regressor': SVR()
# }

# for model_name, model in models.items():
#     model.fit(x_train, y_train)
#     y_pred = model.predict(x_test)

#     # Evaluate the model
#     r2 = r2_score(y_test, y_pred)
#     mae = mean_absolute_error(y_test, y_pred)
#     rmse = np.sqrt(mean_squared_error(y_test, y_pred))
#     scoree = model.score(x_test,y_test)

#     print(f'{model_name}:')
#     print(f'R-squared: {r2:.2f}')
#     print(f'Mean Absolute Error (MAE): {mae:.2f}')
#     print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
#     print(f'Accuracy of Model:{scoree:.2f}')
#     print('****************************************')

# %%
model = RandomForestRegressor(random_state=42)

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %% [markdown]
# ### Integrate mlFlow

# %%
import mlflow
import mlflow.sklearn
import mlflow.xgboost

# %% [markdown]
# ### DagsHub Setup

# %%
import dagshub
dagshub.init(repo_owner='ghosh.dipam19', repo_name='End-to-End-House-price-prediction', mlflow=True)
# Out:
#                                        ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=bee73be7-d8a4-4d66-b21f-68d9e8cad017&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=36fcf497b289e60826c6872c93aa18cb5157f74c41984195c39fd1fc965f9ed0
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Accessing as ghosh.dipam19
# Initialized MLflow to track repo "ghosh.dipam19/End-to-End-House-price-prediction"
# Repository ghosh.dipam19/End-to-End-House-price-prediction initialized!
# 🏃 View run nebulous-fly-182 at: https://dagshub.com/ghosh.dipam19/End-to-End-House-price-prediction.mlflow/#/experiments/0/runs/93505e3cd3d348b3afef702c6be0f0e5
# 🧪 View experiment at: https://dagshub.com/ghosh.dipam19/End-to-End-House-price-prediction.mlflow/#/experiments/0

# %% [markdown]
# ##Save the model

# %%
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
score = model.score(x_test,y_test)

# %%
print(f'R-squared: {r2:.2f}')
print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
print(f'Accuracy of Model:{score:.2f}')
# Out:
# R-squared: 0.92
# Mean Absolute Error (MAE): 642509.73
# Root Mean Squared Error (RMSE): 4206864.63
# Accuracy of Model:0.92

# %%
import os
os.environ['MLFLOW_TRACKING_USERNAME'] = 'ghosh.dipam19'
os.environ['MLFLOW_TRACKING_PASSWORD'] = 'Nilgunj@123'
os.environ['MLFLOW_TRACKING_URI'] = 'https://dagshub.com/ghosh.dipam19/End-to-End-House-price-prediction.mlflow'

# %%
mlflow.set_tracking_uri("https://dagshub.com/ghosh.dipam19/End-to-End-House-price-prediction.mlflow")
mlflow.set_experiment("House_Price_Prediction")


# Start an MLflow run
with mlflow.start_run(run_name="RFR-Dg"):
    # Log the hyperparameters
    # mlflow.log_params(params)
    
    # mlflow.log_metric("R-squared", r2)
    # mlflow.log_metric("Mean Absolute Error (MAE)", mae)
    # mlflow.log_metric("Root Mean Squared Error (RMSE)", rmse)
    mlflow.log_metric("Accuracy", score)

    mlflow.set_tag("Model Type", "Regression")
    mlflow.set_tag("Currency", "Indian Rupees")

    # Log the model
    model_info = mlflow.sklearn.log_model(
        sk_model=model,
        artifact_path="House Price data",
        input_example=x_train,
        registered_model_name="House Price Model",
    )
# Out:
# ...
# Registered model 'House Price Model' already exists. Creating a new version of this model...
# 2025/01/17 22:35:17 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: House Price Model, version 2
# Created version '2' of model 'House Price Model'.
# 🏃 View run RFR-Dg at: https://dagshub.com/ghosh.dipam19/End-to-End-House-price-prediction.mlflow/#/experiments/1/runs/f4047a5a90f141f7834d0446ac12bb0e
# 🧪 View experiment at: https://dagshub.com/ghosh.dipam19/End-to-End-House-price-prediction.mlflow/#/experiments/1

# %%
import joblib

joblib.dump(model, "housePriceModel.pkl")

# Load the model
# loaded_model = joblib.load("housePriceModel.pkl")
# Out:
# ['housePriceModel.pkl']
